# %% [markdown]
# # Permuted Pixel MNIST Demo
# Light weighted demo of our DilatedRNN on Pixel MNist with permutation.

# %%
import sys
sys.path.append("./models")
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from classification_models import drnn_classification

# %%
# configurations
data_dir = "./MNIST_data"
n_steps = 28*28
input_dims = 1
n_classes = 10 

# model config
cell_type = "GRU"
assert(cell_type in ["RNN", "LSTM", "GRU"])
hidden_structs = [20, 30, 40, 50]
dilations = [4, 8, 16, 32]
assert(len(hidden_structs) == len(dilations))

# learning config
batch_size = 128
learning_rate = 1.0e-3
training_iters = batch_size * 30000
testing_step = 5000
display_step = 100

# permutation seed 
seed = 92916

# %%
mnist = input_data.read_data_sets(data_dir, one_hot=True)
if 'seed' in globals():
    rng_permute = np.random.RandomState(seed)
    idx_permute = rng_permute.permutation(n_steps)
else:
    idx_permute = np.random.permutation(n_steps)
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# build computation graph
tf.reset_default_graph()
x = tf.placeholder(tf.float32, [None, n_steps, input_dims])
y = tf.placeholder(tf.float32, [None, n_classes])    
global_step = tf.Variable(0, name='global_step', trainable=False)

# build prediction graph
print ("==> Building a dRNN with %s cells" %cell_type)
pred = drnn_classification(x, hidden_structs, dilations, n_steps, n_classes, input_dims, cell_type)

# build loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate, 0.9).minimize(cost, global_step=global_step)

# evaluation model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# ==> Building a dRNN with GRU cells
# Building layer: multi_dRNN_dilation_4, input length: 784, dilation rate: 4, input dim: 1.
# =====> Input length for sub-RNN: 196
# Building layer: multi_dRNN_dilation_8, input length: 784, dilation rate: 8, input dim: 20.
# =====> Input length for sub-RNN: 98
# Building layer: multi_dRNN_dilation_16, input length: 784, dilation rate: 16, input dim: 30.
# =====> Input length for sub-RNN: 49
# Building layer: multi_dRNN_dilation_32, input length: 784, dilation rate: 32, input dim: 40.
# =====> 16 time points need to be padded.
# =====> Input length for sub-RNN: 25

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
step = 0
train_results = []
validation_results = []
test_results = []

while step * batch_size < training_iters:
    batch_x, batch_y = mnist.train.next_batch(batch_size)    
    batch_x = batch_x[:, idx_permute]
    batch_x = batch_x.reshape([batch_size, n_steps, input_dims])

    feed_dict = {
        x : batch_x,
        y : batch_y
    }
    cost_, accuracy_, step_,  _ = sess.run([cost, accuracy, global_step, optimizer], feed_dict=feed_dict)    
    train_results.append((step_, cost_, accuracy_))    

    if (step + 1) % display_step == 0:
        print ("Iter " + str(step + 1) + ", Minibatch Loss: " + "{:.6f}".format(cost_) \
        + ", Training Accuracy: " + "{:.6f}".format(accuracy_))
             
    if (step + 1) % testing_step == 0:
        
        # validation performance
        batch_x = mnist.validation.images
        batch_y = mnist.validation.labels

        # permute the data
        batch_x = batch_x[:, idx_permute]        
        batch_x = batch_x.reshape([-1, n_steps, input_dims])
        feed_dict = {
            x : batch_x,
            y : batch_y
        }
        cost_, accuracy__, step_ = sess.run([cost, accuracy, global_step], feed_dict=feed_dict)
        validation_results.append((step_, cost_, accuracy__))
        
        # test performance
        batch_x = mnist.test.images
        batch_y = mnist.test.labels
        batch_x = batch_x[:, idx_permute]        
        batch_x = batch_x.reshape([-1, n_steps, input_dims])
        feed_dict = {
            x : batch_x,
            y : batch_y
        }
        cost_, accuracy_, step_ = sess.run([cost, accuracy, global_step], feed_dict=feed_dict)
        test_results.append((step_, cost_, accuracy_))        
        print ("========> Validation Accuarcy: " + "{:.6f}".format(accuracy__) \
        + ", Testing Accuarcy: " + "{:.6f}".format(accuracy_)) 
    step += 1
# Out:
# Iter 100, Minibatch Loss: 1.967738, Training Accuracy: 0.273438
# Iter 200, Minibatch Loss: 1.391636, Training Accuracy: 0.523438
# Iter 300, Minibatch Loss: 1.121808, Training Accuracy: 0.593750
# Iter 400, Minibatch Loss: 0.956666, Training Accuracy: 0.687500
# Iter 500, Minibatch Loss: 0.772850, Training Accuracy: 0.765625
# Iter 600, Minibatch Loss: 0.571083, Training Accuracy: 0.781250
# Iter 700, Minibatch Loss: 0.716546, Training Accuracy: 0.750000
# Iter 800, Minibatch Loss: 0.769885, Training Accuracy: 0.734375
# Iter 900, Minibatch Loss: 0.695285, Training Accuracy: 0.789062
# Iter 1000, Minibatch Loss: 0.643893, Training Accuracy: 0.773438
# Iter 1100, Minibatch Loss: 0.609298, Training Accuracy: 0.789062
# Iter 1200, Minibatch Loss: 0.355377, Training Accuracy: 0.867188
# Iter 1300, Minibatch Loss: 0.485463, Training Accuracy: 0.843750
# Iter 1400, Minibatch Loss: 0.464110, Training Accuracy: 0.867188
# Iter 1500, Minibatch Loss: 0.388008, Training Accuracy: 0.890625
# Iter 1600, Minibatch Loss: 0.482370, Training Accuracy: 0.859375
# Iter 1700, Minibatch Loss: 0.368750, Training Accuracy: 0.882812
# Iter 1800, Minibatch Loss: 0.363097, Training Accuracy: 0.882812
# Iter 1900, Minibatch Loss: 0.361030, Training Accuracy: 0.914062
# Iter 2000, Minibatch Loss: 0.504722, Training Accuracy: 0.812500
# Iter 2100, Minibatch Loss: 0.246328, Training Accuracy: 0.914062
# Iter 2200, Minibatch Loss: 0.262715, Training Accuracy: 0.906250
# Iter 2300, Minibatch Loss: 0.315797, Training Accuracy: 0.898438
# Iter 2400, Minibatch Loss: 0.392971, Training Accuracy: 0.890625
# Iter 2500, Minibatch Loss: 0.369038, Training Accuracy: 0.875000
# Iter 2600, Minibatch Loss: 0.320932, Training Accuracy: 0.890625
# Iter 2700, Minibatch Loss: 0.288877, Training Accuracy: 0.914062
# Iter 2800, Minibatch Loss: 0.261244, Training Accuracy: 0.914062
# Iter 2900, Minibatch Loss: 0.400034, Training Accuracy: 0.921875
# Iter 3000, Minibatch Loss: 0.346815, Training Accuracy: 0.875000
# Iter 3100, Minibatch Loss: 0.283789, Training Accuracy: 0.867188
# Iter 3200, Minibatch Loss: 0.390995, Training Accuracy: 0.914062
# Iter 3300, Minibatch Loss: 0.229664, Training Accuracy: 0.937500
# Iter 3400, Minibatch Loss: 0.330351, Training Accuracy: 0.890625
# Iter 3500, Minibatch Loss: 0.254726, Training Accuracy: 0.921875
# Iter 3600, Minibatch Loss: 0.362524, Training Accuracy: 0.882812
# Iter 3700, Minibatch Loss: 0.299597, Training Accuracy: 0.882812
# Iter 3800, Minibatch Loss: 0.256415, Training Accuracy: 0.929688
# Iter 3900, Minibatch Loss: 0.248506, Training Accuracy: 0.937500
# Iter 4000, Minibatch Loss: 0.282619, Training Accuracy: 0.906250
# Iter 4100, Minibatch Loss: 0.262608, Training Accuracy: 0.914062
# Iter 4200, Minibatch Loss: 0.134028, Training Accuracy: 0.968750
# Iter 4300, Minibatch Loss: 0.278858, Training Accuracy: 0.929688
# Iter 4400, Minibatch Loss: 0.131875, Training Accuracy: 0.945312
# Iter 4500, Minibatch Loss: 0.159796, Training Accuracy: 0.945312
# Iter 4600, Minibatch Loss: 0.225943, Training Accuracy: 0.921875
# Iter 4700, Minibatch Loss: 0.177852, Training Accuracy: 0.921875
# Iter 4800, Minibatch Loss: 0.343069, Training Accuracy: 0.890625
# Iter 4900, Minibatch Loss: 0.180657, Training Accuracy: 0.960938
# Iter 5000, Minibatch Loss: 0.225686, Training Accuracy: 0.929688
# ========> Validation Accuarcy: 0.929200, Testing Accuarcy: 0.926700
# Iter 5100, Minibatch Loss: 0.150706, Training Accuracy: 0.953125
# Iter 5200, Minibatch Loss: 0.134991, Training Accuracy: 0.960938
# Iter 5300, Minibatch Loss: 0.239514, Training Accuracy: 0.937500
# Iter 5400, Minibatch Loss: 0.135103, Training Accuracy: 0.960938
# Iter 5500, Minibatch Loss: 0.148909, Training Accuracy: 0.945312
# Iter 5600, Minibatch Loss: 0.339281, Training Accuracy: 0.882812
# Iter 5700, Minibatch Loss: 0.135437, Training Accuracy: 0.960938
# Iter 5800, Minibatch Loss: 0.255672, Training Accuracy: 0.914062
# Iter 5900, Minibatch Loss: 0.291284, Training Accuracy: 0.953125
# Iter 6000, Minibatch Loss: 0.378674, Training Accuracy: 0.867188
# Iter 6100, Minibatch Loss: 0.273528, Training Accuracy: 0.914062
# Iter 6200, Minibatch Loss: 0.141449, Training Accuracy: 0.953125
# Iter 6300, Minibatch Loss: 0.133697, Training Accuracy: 0.945312
# Iter 6400, Minibatch Loss: 0.228233, Training Accuracy: 0.929688
# Iter 6500, Minibatch Loss: 0.165432, Training Accuracy: 0.945312
# Iter 6600, Minibatch Loss: 0.129234, Training Accuracy: 0.953125
# Iter 6700, Minibatch Loss: 0.142818, Training Accuracy: 0.976562
# Iter 6800, Minibatch Loss: 0.168615, Training Accuracy: 0.953125
# Iter 6900, Minibatch Loss: 0.094020, Training Accuracy: 0.960938
# Iter 18600, Minibatch Loss: 0.027962, Training Accuracy: 1.000000
# Iter 18700, Minibatch Loss: 0.006420, Training Accuracy: 1.000000
# Iter 18800, Minibatch Loss: 0.035908, Training Accuracy: 0.992188
# Iter 18900, Minibatch Loss: 0.025810, Training Accuracy: 0.992188
# Iter 19000, Minibatch Loss: 0.087729, Training Accuracy: 0.968750
# Iter 19100, Minibatch Loss: 0.024368, Training Accuracy: 0.984375
# Iter 19200, Minibatch Loss: 0.013781, Training Accuracy: 0.992188
# Iter 19300, Minibatch Loss: 0.093116, Training Accuracy: 0.992188
# Iter 19400, Minibatch Loss: 0.026082, Training Accuracy: 1.000000
# Iter 19500, Minibatch Loss: 0.035029, Training Accuracy: 0.984375
# Iter 19600, Minibatch Loss: 0.025178, Training Accuracy: 0.992188
# Iter 19700, Minibatch Loss: 0.020063, Training Accuracy: 0.992188
# Iter 19800, Minibatch Loss: 0.017549, Training Accuracy: 1.000000
# Iter 19900, Minibatch Loss: 0.040126, Training Accuracy: 0.992188
# Iter 20000, Minibatch Loss: 0.074063, Training Accuracy: 0.984375
# ========> Validation Accuarcy: 0.952000, Testing Accuarcy: 0.946500
# Iter 20100, Minibatch Loss: 0.010993, Training Accuracy: 1.000000
# Iter 20200, Minibatch Loss: 0.018917, Training Accuracy: 0.992188
# Iter 20300, Minibatch Loss: 0.018562, Training Accuracy: 0.992188
# Iter 20400, Minibatch Loss: 0.026146, Training Accuracy: 1.000000
# Iter 20500, Minibatch Loss: 0.045318, Training Accuracy: 0.992188
# Iter 20600, Minibatch Loss: 0.017386, Training Accuracy: 1.000000
# Iter 20700, Minibatch Loss: 0.025153, Training Accuracy: 1.000000
# Iter 20800, Minibatch Loss: 0.021805, Training Accuracy: 0.992188
# Iter 20900, Minibatch Loss: 0.026987, Training Accuracy: 0.984375
# Iter 21000, Minibatch Loss: 0.009814, Training Accuracy: 1.000000
# Iter 21100, Minibatch Loss: 0.010323, Training Accuracy: 1.000000
# Iter 21200, Minibatch Loss: 0.060324, Training Accuracy: 0.992188
# Iter 21300, Minibatch Loss: 0.046331, Training Accuracy: 0.968750
# Iter 21400, Minibatch Loss: 0.018159, Training Accuracy: 0.992188
# Iter 21500, Minibatch Loss: 0.017654, Training Accuracy: 0.992188
# Iter 21600, Minibatch Loss: 0.014192, Training Accuracy: 1.000000
# Iter 21700, Minibatch Loss: 0.032551, Training Accuracy: 0.984375
# Iter 21800, Minibatch Loss: 0.037279, Training Accuracy: 0.992188
# Iter 21900, Minibatch Loss: 0.011752, Training Accuracy: 1.000000
# Iter 22000, Minibatch Loss: 0.024278, Training Accuracy: 0.984375
# Iter 22100, Minibatch Loss: 0.010403, Training Accuracy: 1.000000
# Iter 22200, Minibatch Loss: 0.028405, Training Accuracy: 0.984375
# Iter 22300, Minibatch Loss: 0.009288, Training Accuracy: 1.000000
# Iter 22400, Minibatch Loss: 0.003007, Training Accuracy: 1.000000
# Iter 22500, Minibatch Loss: 0.002794, Training Accuracy: 1.000000
# Iter 22600, Minibatch Loss: 0.004875, Training Accuracy: 1.000000
# Iter 22700, Minibatch Loss: 0.017262, Training Accuracy: 0.992188
# Iter 22800, Minibatch Loss: 0.008281, Training Accuracy: 1.000000
# Iter 22900, Minibatch Loss: 0.023408, Training Accuracy: 0.984375
# Iter 23000, Minibatch Loss: 0.010594, Training Accuracy: 1.000000
# Iter 23100, Minibatch Loss: 0.025101, Training Accuracy: 0.984375
# Iter 23200, Minibatch Loss: 0.007052, Training Accuracy: 1.000000
# Iter 23300, Minibatch Loss: 0.010900, Training Accuracy: 1.000000
# Iter 23400, Minibatch Loss: 0.012480, Training Accuracy: 1.000000
# Iter 23500, Minibatch Loss: 0.018754, Training Accuracy: 1.000000
# Iter 23600, Minibatch Loss: 0.028700, Training Accuracy: 0.992188
# Iter 23700, Minibatch Loss: 0.007456, Training Accuracy: 1.000000
# Iter 23800, Minibatch Loss: 0.006618, Training Accuracy: 1.000000
# Iter 23900, Minibatch Loss: 0.030566, Training Accuracy: 0.992188
# Iter 24000, Minibatch Loss: 0.018190, Training Accuracy: 0.992188
# Iter 24100, Minibatch Loss: 0.007728, Training Accuracy: 1.000000
# Iter 24200, Minibatch Loss: 0.027661, Training Accuracy: 0.984375
# Iter 24300, Minibatch Loss: 0.004577, Training Accuracy: 1.000000
# Iter 24400, Minibatch Loss: 0.013681, Training Accuracy: 1.000000
# Iter 24500, Minibatch Loss: 0.004770, Training Accuracy: 1.000000
# Iter 24600, Minibatch Loss: 0.011330, Training Accuracy: 1.000000
# Iter 24700, Minibatch Loss: 0.004058, Training Accuracy: 1.000000
# Iter 24800, Minibatch Loss: 0.011746, Training Accuracy: 1.000000
# Iter 24900, Minibatch Loss: 0.009025, Training Accuracy: 1.000000
# Iter 25000, Minibatch Loss: 0.018634, Training Accuracy: 0.992188
# ========> Validation Accuarcy: 0.948400, Testing Accuarcy: 0.944300
# Iter 25100, Minibatch Loss: 0.009597, Training Accuracy: 1.000000
# Iter 25200, Minibatch Loss: 0.019223, Training Accuracy: 0.992188
# Iter 25300, Minibatch Loss: 0.010086, Training Accuracy: 1.000000
# Iter 25400, Minibatch Loss: 0.017891, Training Accuracy: 0.992188
# Iter 25500, Minibatch Loss: 0.002962, Training Accuracy: 1.000000
# Iter 25600, Minibatch Loss: 0.040060, Training Accuracy: 0.984375
# Iter 25700, Minibatch Loss: 0.007816, Training Accuracy: 1.000000
# Iter 25800, Minibatch Loss: 0.008849, Training Accuracy: 1.000000
# Iter 25900, Minibatch Loss: 0.013440, Training Accuracy: 1.000000
# Iter 26000, Minibatch Loss: 0.007615, Training Accuracy: 1.000000
# Iter 26100, Minibatch Loss: 0.021868, Training Accuracy: 0.992188
# Iter 26200, Minibatch Loss: 0.002894, Training Accuracy: 1.000000
# Iter 26300, Minibatch Loss: 0.003181, Training Accuracy: 1.000000
# Iter 26400, Minibatch Loss: 0.028827, Training Accuracy: 0.992188
# Iter 26500, Minibatch Loss: 0.013540, Training Accuracy: 0.992188
# Iter 26600, Minibatch Loss: 0.007872, Training Accuracy: 1.000000
# Iter 26700, Minibatch Loss: 0.024251, Training Accuracy: 0.992188
# Iter 26800, Minibatch Loss: 0.027809, Training Accuracy: 0.984375
# Iter 26900, Minibatch Loss: 0.005921, Training Accuracy: 1.000000
# Iter 27000, Minibatch Loss: 0.006161, Training Accuracy: 1.000000
# Iter 27100, Minibatch Loss: 0.004607, Training Accuracy: 1.000000
# Iter 27200, Minibatch Loss: 0.003551, Training Accuracy: 1.000000
# Iter 27300, Minibatch Loss: 0.014829, Training Accuracy: 0.992188
# Iter 27400, Minibatch Loss: 0.013430, Training Accuracy: 0.992188
# Iter 27500, Minibatch Loss: 0.001091, Training Accuracy: 1.000000
# Iter 27600, Minibatch Loss: 0.002319, Training Accuracy: 1.000000
# Iter 27700, Minibatch Loss: 0.012422, Training Accuracy: 1.000000
# Iter 27800, Minibatch Loss: 0.010821, Training Accuracy: 0.992188
# Iter 27900, Minibatch Loss: 0.029194, Training Accuracy: 0.984375
# Iter 28000, Minibatch Loss: 0.022831, Training Accuracy: 0.992188
# Iter 28100, Minibatch Loss: 0.025779, Training Accuracy: 0.984375
# Iter 28200, Minibatch Loss: 0.002633, Training Accuracy: 1.000000
# Iter 28300, Minibatch Loss: 0.018982, Training Accuracy: 0.992188
# Iter 28400, Minibatch Loss: 0.062087, Training Accuracy: 0.976562
# Iter 28500, Minibatch Loss: 0.003680, Training Accuracy: 1.000000
# Iter 28600, Minibatch Loss: 0.003792, Training Accuracy: 1.000000
# Iter 28700, Minibatch Loss: 0.002112, Training Accuracy: 1.000000
# Iter 28800, Minibatch Loss: 0.006602, Training Accuracy: 1.000000
# Iter 28900, Minibatch Loss: 0.019425, Training Accuracy: 0.992188
# Iter 29000, Minibatch Loss: 0.001841, Training Accuracy: 1.000000
# Iter 29100, Minibatch Loss: 0.001209, Training Accuracy: 1.000000
# Iter 29200, Minibatch Loss: 0.046525, Training Accuracy: 0.976562
# Iter 29300, Minibatch Loss: 0.002254, Training Accuracy: 1.000000
# Iter 29400, Minibatch Loss: 0.011416, Training Accuracy: 1.000000
# Iter 29500, Minibatch Loss: 0.015807, Training Accuracy: 0.992188
# Iter 29600, Minibatch Loss: 0.003624, Training Accuracy: 1.000000
# Iter 29700, Minibatch Loss: 0.008086, Training Accuracy: 0.992188
# Iter 29800, Minibatch Loss: 0.006443, Training Accuracy: 1.000000
# Iter 29900, Minibatch Loss: 0.028255, Training Accuracy: 0.984375
# Iter 30000, Minibatch Loss: 0.003541, Training Accuracy: 1.000000
# ========> Validation Accuarcy: 0.950400, Testing Accuarcy: 0.946500
