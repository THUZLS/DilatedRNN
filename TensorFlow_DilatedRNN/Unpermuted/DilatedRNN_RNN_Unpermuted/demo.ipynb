# %% [markdown]
# # Unpermuted Pixel MNIST Demo
# Light weighted demo of our DilatedRNN on Pixel MNist with permutation.

# %%
import sys
sys.path.append("./models")
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from classification_models import drnn_classification

# %%
# configurations
data_dir = "./MNIST_data"
n_steps = 28*28
input_dims = 1
n_classes = 10 

# model config
cell_type = "RNN"
assert(cell_type in ["RNN", "LSTM", "GRU"])
hidden_structs = [20] * 9
dilations = [1, 2, 4, 8, 16, 32, 64, 128, 256]
assert(len(hidden_structs) == len(dilations))

# learning config
batch_size = 128
learning_rate = 1.0e-3
training_iters = batch_size * 30000
testing_step = 5000
display_step = 100

# %%
mnist = input_data.read_data_sets(data_dir, one_hot=True)
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# build computation graph
tf.reset_default_graph()
x = tf.placeholder(tf.float32, [None, n_steps, input_dims])
y = tf.placeholder(tf.float32, [None, n_classes])    
global_step = tf.Variable(0, name='global_step', trainable=False)

# build prediction graph
print ("==> Building a dRNN with %s cells" %cell_type)
pred = drnn_classification(x, hidden_structs, dilations, n_steps, n_classes, input_dims, cell_type)

# build loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate, 0.9).minimize(cost, global_step=global_step)

# evaluation model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# ==> Building a dRNN with RNN cells
# Building layer: multi_dRNN_dilation_1, input length: 784, dilation rate: 1, input dim: 1.
# =====> Input length for sub-RNN: 784
# Building layer: multi_dRNN_dilation_2, input length: 784, dilation rate: 2, input dim: 20.
# =====> Input length for sub-RNN: 392
# Building layer: multi_dRNN_dilation_4, input length: 784, dilation rate: 4, input dim: 20.
# =====> Input length for sub-RNN: 196
# Building layer: multi_dRNN_dilation_8, input length: 784, dilation rate: 8, input dim: 20.
# =====> Input length for sub-RNN: 98
# Building layer: multi_dRNN_dilation_16, input length: 784, dilation rate: 16, input dim: 20.
# =====> Input length for sub-RNN: 49
# Building layer: multi_dRNN_dilation_32, input length: 784, dilation rate: 32, input dim: 20.
# =====> 16 time points need to be padded.
# =====> Input length for sub-RNN: 25
# Building layer: multi_dRNN_dilation_64, input length: 784, dilation rate: 64, input dim: 20.
# =====> 48 time points need to be padded.
# =====> Input length for sub-RNN: 13
# Building layer: multi_dRNN_dilation_128, input length: 784, dilation rate: 128, input dim: 20.
# =====> 112 time points need to be padded.
# =====> Input length for sub-RNN: 7
# Building layer: multi_dRNN_dilation_256, input length: 784, dilation rate: 256, input dim: 20.
# =====> 240 time points need to be padded.
# =====> Input length for sub-RNN: 4
# WARNING:tensorflow:From <ipython-input-4-7aeba9471f6b>:12: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
step = 0
train_results = []
validation_results = []
test_results = []

while step * batch_size < training_iters:
    batch_x, batch_y = mnist.train.next_batch(batch_size)    
    batch_x = batch_x.reshape([batch_size, n_steps, input_dims])

    feed_dict = {
        x : batch_x,
        y : batch_y
    }
    cost_, accuracy_, step_,  _ = sess.run([cost, accuracy, global_step, optimizer], feed_dict=feed_dict)    
    train_results.append((step_, cost_, accuracy_))    

    if (step + 1) % display_step == 0:
        print ("Iter " + str(step + 1) + ", Minibatch Loss: " + "{:.6f}".format(cost_) \
        + ", Training Accuracy: " + "{:.6f}".format(accuracy_))
             
    if (step + 1) % testing_step == 0:
        
        # validation performance
        batch_x = mnist.validation.images
        batch_y = mnist.validation.labels

        # unpermute the data 
        batch_x = batch_x.reshape([-1, n_steps, input_dims])
        feed_dict = {
            x : batch_x,
            y : batch_y
        }
        cost_, accuracy__, step_ = sess.run([cost, accuracy, global_step], feed_dict=feed_dict)
        validation_results.append((step_, cost_, accuracy__))
        
        # test performance
        batch_x = mnist.test.images
        batch_y = mnist.test.labels  
        batch_x = batch_x.reshape([-1, n_steps, input_dims])
        feed_dict = {
            x : batch_x,
            y : batch_y
        }
        cost_, accuracy_, step_ = sess.run([cost, accuracy, global_step], feed_dict=feed_dict)
        test_results.append((step_, cost_, accuracy_))        
        print ("========> Validation Accuarcy: " + "{:.6f}".format(accuracy__) \
        + ", Testing Accuarcy: " + "{:.6f}".format(accuracy_)) 
    step += 1
# Out:
# Iter 100, Minibatch Loss: 1.052948, Training Accuracy: 0.726562
# Iter 200, Minibatch Loss: 0.461022, Training Accuracy: 0.859375
# Iter 300, Minibatch Loss: 0.373161, Training Accuracy: 0.882812
# Iter 400, Minibatch Loss: 0.152389, Training Accuracy: 0.968750
# Iter 500, Minibatch Loss: 0.300999, Training Accuracy: 0.882812
# Iter 600, Minibatch Loss: 0.237531, Training Accuracy: 0.929688
# Iter 700, Minibatch Loss: 0.208678, Training Accuracy: 0.937500
# Iter 800, Minibatch Loss: 0.189831, Training Accuracy: 0.953125
# Iter 900, Minibatch Loss: 0.217539, Training Accuracy: 0.929688
# Iter 1000, Minibatch Loss: 0.152126, Training Accuracy: 0.960938
# Iter 1100, Minibatch Loss: 0.219170, Training Accuracy: 0.945312
# Iter 1200, Minibatch Loss: 0.219927, Training Accuracy: 0.960938
# Iter 1300, Minibatch Loss: 0.124619, Training Accuracy: 0.937500
# Iter 1400, Minibatch Loss: 0.187450, Training Accuracy: 0.945312
# Iter 1500, Minibatch Loss: 0.125620, Training Accuracy: 0.953125
# Iter 1600, Minibatch Loss: 0.247766, Training Accuracy: 0.921875
# Iter 1700, Minibatch Loss: 0.163321, Training Accuracy: 0.937500
# Iter 1800, Minibatch Loss: 0.130770, Training Accuracy: 0.976562
# Iter 1900, Minibatch Loss: 0.120715, Training Accuracy: 0.953125
# Iter 2000, Minibatch Loss: 0.103183, Training Accuracy: 0.968750
# Iter 2100, Minibatch Loss: 0.136377, Training Accuracy: 0.960938
# Iter 2200, Minibatch Loss: 0.177438, Training Accuracy: 0.953125
# Iter 2300, Minibatch Loss: 0.070426, Training Accuracy: 0.984375
# Iter 2400, Minibatch Loss: 0.110194, Training Accuracy: 0.984375
# Iter 2500, Minibatch Loss: 0.090979, Training Accuracy: 0.976562
# Iter 2600, Minibatch Loss: 0.165910, Training Accuracy: 0.968750
# Iter 2700, Minibatch Loss: 0.141408, Training Accuracy: 0.945312
# Iter 2800, Minibatch Loss: 0.127851, Training Accuracy: 0.960938
# Iter 2900, Minibatch Loss: 0.081700, Training Accuracy: 0.968750
# Iter 3000, Minibatch Loss: 0.151526, Training Accuracy: 0.945312
# Iter 3100, Minibatch Loss: 0.022436, Training Accuracy: 1.000000
# Iter 3200, Minibatch Loss: 0.105210, Training Accuracy: 0.976562
# Iter 3300, Minibatch Loss: 0.060353, Training Accuracy: 0.984375
# Iter 3400, Minibatch Loss: 0.138322, Training Accuracy: 0.960938
# Iter 3500, Minibatch Loss: 0.070437, Training Accuracy: 0.976562
# Iter 3600, Minibatch Loss: 0.081258, Training Accuracy: 0.968750
# Iter 3700, Minibatch Loss: 0.118118, Training Accuracy: 0.976562
# Iter 3800, Minibatch Loss: 0.062660, Training Accuracy: 0.984375
# Iter 3900, Minibatch Loss: 0.077379, Training Accuracy: 0.976562
# Iter 4000, Minibatch Loss: 0.050232, Training Accuracy: 0.984375
# Iter 4100, Minibatch Loss: 0.065327, Training Accuracy: 0.984375
# Iter 4200, Minibatch Loss: 0.194841, Training Accuracy: 0.953125
# Iter 4300, Minibatch Loss: 0.145782, Training Accuracy: 0.968750
# Iter 4400, Minibatch Loss: 0.116924, Training Accuracy: 0.968750
# Iter 4500, Minibatch Loss: 0.090187, Training Accuracy: 0.976562
# Iter 4600, Minibatch Loss: 0.047797, Training Accuracy: 0.992188
# Iter 4700, Minibatch Loss: 0.124542, Training Accuracy: 0.968750
# Iter 4800, Minibatch Loss: 0.034153, Training Accuracy: 0.992188
# Iter 4900, Minibatch Loss: 0.066135, Training Accuracy: 0.976562
# Iter 5000, Minibatch Loss: 0.065278, Training Accuracy: 0.968750
# ========> Validation Accuarcy: 0.975800, Testing Accuarcy: 0.975500
# Iter 5100, Minibatch Loss: 0.054833, Training Accuracy: 0.984375
# Iter 5200, Minibatch Loss: 0.074973, Training Accuracy: 0.968750
# Iter 5300, Minibatch Loss: 0.051256, Training Accuracy: 0.976562
# Iter 5400, Minibatch Loss: 0.092072, Training Accuracy: 0.960938
# Iter 5500, Minibatch Loss: 0.114208, Training Accuracy: 0.968750
# Iter 5600, Minibatch Loss: 0.088736, Training Accuracy: 0.976562
# Iter 5700, Minibatch Loss: 0.066713, Training Accuracy: 0.976562
# Iter 5800, Minibatch Loss: 0.086202, Training Accuracy: 0.968750
# Iter 5900, Minibatch Loss: 0.046260, Training Accuracy: 0.992188
# Iter 6000, Minibatch Loss: 0.025855, Training Accuracy: 0.992188
# Iter 6100, Minibatch Loss: 0.102919, Training Accuracy: 0.968750
# Iter 6200, Minibatch Loss: 0.189072, Training Accuracy: 0.968750
# Iter 6300, Minibatch Loss: 0.054644, Training Accuracy: 0.976562
# Iter 6400, Minibatch Loss: 0.102980, Training Accuracy: 0.984375
# Iter 6500, Minibatch Loss: 0.066034, Training Accuracy: 0.976562
# Iter 6600, Minibatch Loss: 0.018120, Training Accuracy: 1.000000
# Iter 6700, Minibatch Loss: 0.102902, Training Accuracy: 0.968750
# Iter 6800, Minibatch Loss: 0.078040, Training Accuracy: 0.976562
# Iter 6900, Minibatch Loss: 0.040583, Training Accuracy: 0.984375
# Iter 7000, Minibatch Loss: 0.099152, Training Accuracy: 0.968750
# Iter 7100, Minibatch Loss: 0.095278, Training Accuracy: 0.984375
# Iter 7200, Minibatch Loss: 0.078950, Training Accuracy: 0.968750
# Iter 7300, Minibatch Loss: 0.016803, Training Accuracy: 1.000000
# Iter 7400, Minibatch Loss: 0.052494, Training Accuracy: 0.992188
# Iter 7500, Minibatch Loss: 0.145773, Training Accuracy: 0.945312
# Iter 7600, Minibatch Loss: 0.180414, Training Accuracy: 0.953125
# Iter 7700, Minibatch Loss: 0.103183, Training Accuracy: 0.984375
# Iter 7800, Minibatch Loss: 0.101650, Training Accuracy: 0.968750
# Iter 7900, Minibatch Loss: 0.071576, Training Accuracy: 0.976562
# Iter 8000, Minibatch Loss: 0.024386, Training Accuracy: 0.992188
# Iter 8100, Minibatch Loss: 0.098471, Training Accuracy: 0.960938
# Iter 8200, Minibatch Loss: 0.039122, Training Accuracy: 0.984375
# Iter 8300, Minibatch Loss: 0.051033, Training Accuracy: 0.992188
# Iter 8400, Minibatch Loss: 0.172558, Training Accuracy: 0.968750
# Iter 8500, Minibatch Loss: 0.166341, Training Accuracy: 0.968750
# Iter 8600, Minibatch Loss: 0.027912, Training Accuracy: 1.000000
# Iter 8700, Minibatch Loss: 0.030158, Training Accuracy: 0.992188
# Iter 8800, Minibatch Loss: 0.052465, Training Accuracy: 0.976562
# Iter 8900, Minibatch Loss: 0.043625, Training Accuracy: 0.984375
# Iter 9000, Minibatch Loss: 0.027306, Training Accuracy: 0.992188
# Iter 9100, Minibatch Loss: 0.048547, Training Accuracy: 0.984375
# Iter 9200, Minibatch Loss: 0.060550, Training Accuracy: 0.968750
# Iter 9300, Minibatch Loss: 0.013322, Training Accuracy: 1.000000
# Iter 9400, Minibatch Loss: 0.048040, Training Accuracy: 0.968750
# Iter 9500, Minibatch Loss: 0.013727, Training Accuracy: 1.000000
# Iter 9600, Minibatch Loss: 0.080932, Training Accuracy: 0.968750
# Iter 9700, Minibatch Loss: 0.044483, Training Accuracy: 0.984375
# Iter 9800, Minibatch Loss: 0.027042, Training Accuracy: 0.984375
# Iter 9900, Minibatch Loss: 0.016048, Training Accuracy: 1.000000
# Iter 10000, Minibatch Loss: 0.061808, Training Accuracy: 0.968750
# ========> Validation Accuarcy: 0.978800, Testing Accuarcy: 0.978700
# Iter 10100, Minibatch Loss: 0.048784, Training Accuracy: 0.992188
# Iter 10200, Minibatch Loss: 0.100539, Training Accuracy: 0.968750
# Iter 10300, Minibatch Loss: 0.054027, Training Accuracy: 0.984375
# Iter 10400, Minibatch Loss: 0.019950, Training Accuracy: 0.992188
# Iter 10500, Minibatch Loss: 0.039549, Training Accuracy: 0.976562
# Iter 10600, Minibatch Loss: 0.110506, Training Accuracy: 0.968750
# Iter 10700, Minibatch Loss: 0.032947, Training Accuracy: 0.992188
# Iter 10800, Minibatch Loss: 0.019374, Training Accuracy: 0.992188
# Iter 10900, Minibatch Loss: 0.016044, Training Accuracy: 1.000000
# Iter 11000, Minibatch Loss: 0.051381, Training Accuracy: 0.984375
